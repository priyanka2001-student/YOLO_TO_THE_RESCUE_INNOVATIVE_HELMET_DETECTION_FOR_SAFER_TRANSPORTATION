# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 28.1 MB/s eta 0:00:00
# ...

# %%
import os

# %%
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolo/data.yaml epochs=50 imgsz=640 batch=8 project=/content/drive/MyDrive/yolo/training_results name=Helmet
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 257MB/s]
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo/training_results/Helmet/weights/best.pt conf=0.35 source=/content/drive/MyDrive/yolo/test_images/test/images
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/63 /content/drive/MyDrive/yolo/test_images/test/images/BikesHelmets102_png_jpg.rf.6bc6d292ee31801b348ecd1b3ff56e58.jpg: 640x640 2 With Helmets, 16.3ms
# image 2/63 /content/drive/MyDrive/yolo/test_images/test/images/BikesHelmets150_png_jpg.rf.347400d070a36faf53bd1ace27a3dd43.jpg: 640x640 5 With Helmets, 1 Without Helmet, 16.3ms
# image 3/63 /content/drive/MyDrive/yolo/test_images/test/images/BikesHelmets162_png_jpg.rf.afa7afdd78e5dd465e07020c8f6f8743.jpg: 640x640 1 With Helmet, 16.4ms
# image 4/63 /content/drive/MyDrive/yolo/test_images/test/images/BikesHelmets163_png_jpg.rf.bc2e75700813e81ee03981e79151f0ac.jpg: 640x640 5 With Helmets, 16.3ms
# image 5/63 /content/drive/MyDrive/yolo/test_images/test/images/BikesHelmets176_png_jpg.rf.80db740fa43cad753ab10b2c62fa7bc6.jpg: 640x640 2 Without Helmets, 16.4ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolo/output
